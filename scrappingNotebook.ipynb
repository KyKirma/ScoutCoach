# %%
import pandas as pd

# %%
df = pd.read_csv('datasetFlashScore2.csv', delimiter=';')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HomeTeam  380 non-null    object
#  1   AwayTeam  380 non-null    object
#  2   DateTime  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   HGE       380 non-null    object
#  6   AGE       380 non-null    object
#  7   HPB       380 non-null    object
#  8   APB       380 non-null    object
#  9   HTG       380 non-null    int64
#  10  ATG       380 non-null    int64
#  11  HCG       380 non-null    int64
#  12  ACG       380 non-null    int64
#  13  HCF       380 non-null    int64
#  14  ACF       380 non-null    int64
#  15  HCB       380 non-null    object
#  16  ACB       380 non-null    object
#  17  HFC       380 non-null    object
#  18  AFC       380 non-null    object
#  19  HES       380 non-null    int64
#  20  AES       380 non-null    int64
#  21  HIP       380 non-null    int64
#  22  AIP       380 non-null    int64
#  23  HLC       380 non-null    object
#  24  ALC       380 non-null    object
#  25  HDG       380 non-null    int64
#  26  ADG       380 non-null    int64
#  27  HFT       380 non-null    int64
#  28  AFT       380 non-null    int64
#  29  HCV       380 non-null    object
#  30  ACV       380 non-null    object
#  31  HCA       380 non-null    object
#  32  ACA       380 non-null    object
#  33  HPT       380 non-null    object
#  34  APT       380 non-null    object
#  35  HPC       380 non-null    object
#  36  APC       380 non-null    object
#  37  HATK      380 non-null    int64
#  38  AATK      380 non-null    int64
#  39  HATKP     380 non-null    int64
#  40  AATKP     380 non-null    int64
# dtypes: int64(20), object(21)
# memory usage: 121.8+ KB

# %%
jogos_casa = df[df['HomeTeam'].str.contains("Flamengo", case=False) | df['AwayTeam'].str.contains("Flamengo", case=False)]

jogos_casa
# Out:
#                 HomeTeam             AwayTeam          DateTime  FTHG  FTAG  \
# 7              São Paulo             Flamengo  06.12.2023 21:30     1     0
# 16              Flamengo               Cuiabá  03.12.2023 16:00     2     1
# 27              Flamengo          Atlético-MG  29.11.2023 19:30     0     3
# 31            América-MG             Flamengo  26.11.2023 18:30     0     3
# 40              Flamengo  Red Bull Bragantino  23.11.2023 21:30     1     0
# 53              Flamengo           Fluminense  11.11.2023 18:30     1     1
# 59              Flamengo            Palmeiras  08.11.2023 21:30     3     0
# 68             Fortaleza             Flamengo  05.11.2023 16:00     0     2
# 79              Flamengo               Santos  01.11.2023 20:00     1     2
# 94                Grêmio             Flamengo  25.10.2023 21:30     3     2
# 104             Flamengo                Vasco  22.10.2023 16:00     1     0
# 112             Cruzeiro             Flamengo  19.10.2023 19:00     0     2
# 127          Corinthians             Flamengo  07.10.2023 21:00     1     1
# 138             Flamengo                Bahia  30.09.2023 16:00     1     0
# 149                Goiás             Flamengo  20.09.2023 19:00     0     0
# 161             Flamengo         Athletico-PR  13.09.2023 21:30     0     3
# 169             Botafogo             Flamengo  02.09.2023 21:00     1     2
# 181             Flamengo        Internacional  26.08.2023 18:30     0     0
# 184             Coritiba             Flamengo  20.08.2023 16:00     2     3
# 195             Flamengo            São Paulo  13.08.2023 18:30     1     1
# 235  0.87  0.35  52%  48%   15  ...    7    5  471  360  396  306  102   93
# 245  1.01  0.94  42%  58%   13  ...    2    3  407  541  338  471   89  125
# 258  1.34  1.49  50%  50%   10  ...    2    0  554  357  476  293  133   98
# 263  1.64  0.95  38%  62%   12  ...    2    1  346  722  291  635   75  175
# 270  3.32  0.65  54%  46%   30  ...    -    -  531  353  441  275  156   67
# 280  1.28  1.90  57%  43%   15  ...    0    3  471  441  400  362  126  106
# 290  1.70  0.73  41%  59%   13  ...    2    0  414  556  337  489  123   97
# 307  2.08  1.09  66%  34%   13  ...    4    5  611  402  544  334  144   92
# 312  0.56  0.92  60%  40%   10  ...    0    2  609  344  560  279  153   70
# 329  0.95  2.44  51%  49%   21  ...    8    5  434  376  369  331  103   86
# 336  2.45  0.66  57%  43%   20  ...    0    1  576  451  513  374   90   72
# 344  1.16  1.26  40%  60%   11  ...    2    2  347  543  277  449   67  124
# 353  3.14  2.03  74%  26%   25  ...    4    4    -    -    -    -  150   58
# 365  1.09  1.78  36%  64%   16  ...    3    1  310  586  251  515   87  129
# 372  1.51  0.39  59%  41%   15  ...    3    3  542  379  480  323  147   96
#
#     HATKP  AATKP
# 7      26     49
# 16     40     28
# 27     93     16
# 31     41     67
# 40     46     38
# 53     55     30
# 59     43     35
# 68     58     33
# 79     25     40
# 94     58     46
# 104    40     46
# 112    52     28
# 127    45     51
# 138    86     28
# 149    33     48
# 161    45     24
# 169    53     39
# 181    53     25
# 184    39     45
# 195    83     25
# 202    46     87
# 216     9     23
# 230    56     38
# 235    53     51
# 245    42     55
# 258    50     43
# 263    20     89
# 270    85     30
# 280    45     72
# 290    51     29
# 307    73     40
# 312    74     35
# 329    65     40
# 336    66     20
# 344    43     67
# 353    87     26
# 365    41     51
# 372    82     26
#
# [38 rows x 41 columns]

# %%
def GoalsSC(df, team):
    dfTime = df[df['HomeTeam'].str.contains(team, case=False) | df['AwayTeam'].str.contains(team, case=False)]

    data = {
        'SCORING': ['Goals scored (GF)', 'GF per match', 'Goals conceded (GA)', 'GA per match', 'GF + GA per match'],
        'Home': [0, 0, 0, 0, 0],
        'Away': [0, 0, 0, 0, 0],
        'All': [0, 0, 0, 0, 0]
    }

    dfGoals = pd.DataFrame(data)
    dfGoals = dfGoals.set_index('SCORING')
    
    # Set 'Goals scored (GF)'
    dfGoals.loc['Goals scored (GF)', 'Home'] = dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum()
    dfGoals.loc['Goals scored (GF)', 'Away'] = dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum()
    dfGoals.loc['Goals scored (GF)', 'All'] =  dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']

    # Set 'GF per match'
    dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
    dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
    dfGoals.loc['GF per match', 'All'] = round((dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']) / len(dfTime), 2)
    """ 
    # Set 'Goals conceded (GA)'
    dfGoals.loc['Goals conceded (GA)', 'Home'] = dfTime[dfTime['Home/Away'] == 'Home']['GA'].sum()
    dfGoals.loc['Goals conceded (GA)', 'Away'] = dfTime[dfTime['Home/Away'] == 'Away']['GA'].sum()
    dfGoals.loc['Goals conceded (GA)', 'All'] = dfTime['GA'].sum()

    # Set 'GA per match'
    dfGoals.loc['GA per match', 'Home'] = len(dfTime[dfTime['Home/Away'] == 'Home'])
    dfGoals.loc['GA per match', 'Away'] = len(dfTime[dfTime['Home/Away'] == 'Away'])
    dfGoals.loc['GA per match', 'All'] = len(dfTime) 
    """

    # Set 'GF + GA per match'

    return dfGoals


GoalsSC(df, 'Flamengo')
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['Goals scored (GF)', 'Home'] = dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['Goals scored (GF)', 'Away'] = dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.68' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.79' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_25800\1002602562.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.47' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'All'] = round((dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']) / len(dfTime), 2)
#                       Home   Away    All
# SCORING
# Goals scored (GF)    26.00  30.00  56.00
# GF per match          0.68   0.79   1.47
# Goals conceded (GA)   0.00   0.00   0.00
# GA per match          0.00   0.00   0.00
# GF + GA per match     0.00   0.00   0.00
