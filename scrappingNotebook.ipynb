# %%
import pandas as pd

# %%
df = pd.read_csv('datasetFlashScore2.csv', delimiter=';')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HomeTeam  110 non-null    object
#  1   AwayTeam  110 non-null    object
#  2   DateTime  110 non-null    object
#  3   FTHG      110 non-null    int64
#  4   FTAG      110 non-null    int64
#  5   HGE       110 non-null    object
#  6   AGE       110 non-null    object
#  7   HPB       110 non-null    object
#  8   APB       110 non-null    object
#  9   HTG       110 non-null    object
#  10  ATG       110 non-null    object
#  11  HCG       110 non-null    int64
#  12  ACG       110 non-null    int64
#  13  HCF       110 non-null    int64
#  14  ACF       110 non-null    int64
#  15  HCB       110 non-null    int64
#  16  ACB       110 non-null    int64
#  17  HFC       110 non-null    int64
#  18  AFC       110 non-null    int64
#  19  HES       110 non-null    int64
#  20  AES       110 non-null    int64
#  21  HIP       110 non-null    int64
#  22  AIP       110 non-null    int64
#  23  HLC       110 non-null    int64
#  24  ALC       110 non-null    int64
#  25  HDG       110 non-null    int64
#  26  ADG       110 non-null    int64
#  27  HFT       110 non-null    int64
#  28  AFT       110 non-null    int64
#  29  HCV       110 non-null    int64
#  30  ACV       110 non-null    int64
#  31  HCA       110 non-null    int64
#  32  ACA       110 non-null    int64
#  33  HPT       110 non-null    int64
#  34  APT       110 non-null    int64
#  35  HPC       110 non-null    int64
#  36  APC       110 non-null    int64
#  37  HATK      110 non-null    int64
#  38  AATK      110 non-null    int64
#  39  HATKP     110 non-null    int64
#  40  AATKP     110 non-null    int64
# dtypes: int64(32), object(9)
# memory usage: 35.4+ KB

# %%
jogos_casa = df[df['HomeTeam'].str.contains("Flamengo", case=False) | df['AwayTeam'].str.contains("Flamengo", case=False)]

jogos_casa
# Out:
#        HomeTeam             AwayTeam          DateTime  FTHG  FTAG HGE AGE  \
# 7     São Paulo             Flamengo  06.12.2023 21:30     1     0   -   -
# 16     Flamengo               Cuiabá  03.12.2023 16:00     2     1   -   -
# 27     Flamengo          Atlético-MG  29.11.2023 19:30     0     3   -   -
# 31   América-MG             Flamengo  26.11.2023 18:30     0     3   -   -
# 40     Flamengo  Red Bull Bragantino  23.11.2023 21:30     1     0   -   -
# 53     Flamengo           Fluminense  11.11.2023 18:30     1     1   -   -
# 59     Flamengo            Palmeiras  08.11.2023 21:30     3     0   -   -
# 68    Fortaleza             Flamengo  05.11.2023 16:00     0     2   -   -
# 79     Flamengo               Santos  01.11.2023 20:00     1     2   -   -
# 94       Grêmio             Flamengo  25.10.2023 21:30     3     2   -   -
# 104    Flamengo                Vasco  22.10.2023 16:00     1     0   -   -
#
#       HPB   APB  HTG  ... HCA  ACA  HPT  APT  HPC  APC  HATK  AATK  HATKP  \
# 7    0.52  0.44  47%  ...  13   16    0    3  422  545   367   479     73
# 16   1.66  0.95  67%  ...  12    9    2    1  652  297   602   248     61
# 27   0.96  1.25  55%  ...  12   12    3    2  594  423   511   355    158
# 31   0.41  2.81  44%  ...   9   13    4    4  398  548   334   466     80
# 40   1.12  1.17  54%  ...  11   15    0    1    4    3   439   375    351
# 53   0.93  1.44  43%  ...  13   17    1    1    1    4   414   554    337
# 59   1.23  0.85  51%  ...  13   17    0    1    1    1   517   490    470
# 68   0.76  0.68  50%  ...   9   11    1    3  527  436   448   370    125
# 79   1.09  0.60  54%  ...  13   16    2    1    2    3   536   344    473
# 94   1.06  1.21  38%  ...  14   16    3    4  377  639   302   569    102
# 104  0.47  0.88  49%  ...  10   15    1    2  400  476   336   386     98
#
#      AATKP
# 7      112
# 16      52
# 27      78
# 31     104
# 40     308
# 53     499
# 59     441
# 68      99
# 79     286
# 94      98
# 104    112
#
# [11 rows x 41 columns]

# %%
def GoalsSC(df, team):
    dfTime = df[df['HomeTeam'].str.contains(team, case=False) | df['AwayTeam'].str.contains(team, case=False)]

    data = {
        'SCORING': ['Goals scored (GF)', 'GF per match', 'Goals conceded (GA)', 'GA per match', 'GF + GA per match'],
        'Home': [0, 0, 0, 0, 0],
        'Away': [0, 0, 0, 0, 0],
        'All': [0, 0, 0, 0, 0]
    }

    dfGoals = pd.DataFrame(data)
    dfGoals = dfGoals.set_index('SCORING')
    
    # Set 'Goals scored (GF)'
    dfGoals.loc['Goals scored (GF)', 'Home'] = dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum()
    dfGoals.loc['Goals scored (GF)', 'Away'] = dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum()
    dfGoals.loc['Goals scored (GF)', 'All'] =  dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']

    # Set 'GF per match'
    # Set 'GF per match'
    dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
    dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
    dfGoals.loc['GF per match', 'All'] = round((dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']) / len(dfTime), 2)
    """ 
    # Set 'Goals conceded (GA)'
    dfGoals.loc['Goals conceded (GA)', 'Home'] = dfTime[dfTime['Home/Away'] == 'Home']['GA'].sum()
    dfGoals.loc['Goals conceded (GA)', 'Away'] = dfTime[dfTime['Home/Away'] == 'Away']['GA'].sum()
    dfGoals.loc['Goals conceded (GA)', 'All'] = dfTime['GA'].sum()

    # Set 'GA per match'
    dfGoals.loc['GA per match', 'Home'] = len(dfTime[dfTime['Home/Away'] == 'Home'])
    dfGoals.loc['GA per match', 'Away'] = len(dfTime[dfTime['Home/Away'] == 'Away'])
    dfGoals.loc['GA per match', 'All'] = len(dfTime) 
    """

    # Set 'GF + GA per match'

    return dfGoals


GoalsSC(df, 'Flamengo')
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['Goals scored (GF)', 'Home'] = dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['Goals scored (GF)', 'Away'] = dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.82' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'Home'] = round(dfTime[(df['HomeTeam'].str.contains(team, case=False)) & (df['FTHG'] > 0)]['FTHG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'Away'] = round(dfTime[(df['AwayTeam'].str.contains(team, case=False)) & (df['FTAG'] > 0)]['FTAG'].sum() / len(dfTime), 2)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11108\3425177528.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.45' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfGoals.loc['GF per match', 'All'] = round((dfGoals.at['Goals scored (GF)', 'Home'] + dfGoals.at['Goals scored (GF)', 'Away']) / len(dfTime), 2)
#                      Home  Away    All
# SCORING
# Goals scored (GF)    9.00  7.00  16.00
# GF per match         0.82  0.64   1.45
# Goals conceded (GA)  0.00  0.00   0.00
# GA per match         0.00  0.00   0.00
# GF + GA per match    0.00  0.00   0.00
