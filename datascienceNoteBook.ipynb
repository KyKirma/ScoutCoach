# %% [markdown]
# Arquivo feito para testes e visualizar os df manipulados

# %%
import pandas as pd
import os
from main import db, app
from models import Campeonato, Times, TPC, Jogo

# %%
CSVPath = "./DataBase"
CSVFiles = os.listdir(CSVPath)

# %%
class TCP:
    def __init__(self, CampAno, Div, Time):
        self.CampAno = CampAno
        self.Div = Div
        self.Time = Time

# %%
div_to_regiao = {
'B': 'Belgica',
'D': 'Alemanha',
'E': 'Inglaterra',
'F': 'França',
'G': 'Grecia',
'I': 'Italia',
'N': 'Holanda',
'P': 'Portugal',
'SC': 'Escocia',
'SP': 'Espanha',
'T': 'Turquia',
}

ListaTimes = []
ListaCamp = []
ListaJogos = []
ListaTCP = []

for arquivos_csv in CSVFiles:
    df = pd.read_csv(os.path.join(CSVPath, arquivos_csv))
    df['Regiao'] = df['Div'].str.extract(r'(\D{1,2})\d?')[0].map(div_to_regiao)
    df['Ano'] = df['Date'].str.extract(r'(\d{4})')

    #Tabela Campeonatos
    div = df['Div'].iloc[0]
    regiao = df['Regiao'].iloc[0]
    ano = df['Ano'].iloc[0]
    nome = "{} {} {}".format(div, regiao, ano)
    ListaCamp.append(Campeonato(div = div, ano = ano, regiao = regiao, nome = nome))

    for index, row in df.iterrows():
        #Tabela Times
        home_team = row['HomeTeam']
        away_team = row['AwayTeam']
        ListaTimes.append(home_team)
        ListaTimes.append(away_team)

        #Tabela Jogos
        div = row['Div']
        regiao = row['Regiao']
        ano = row['Ano']
        nome = "{} {} {}".format(div, regiao, ano)
        ListaJogos.append(Jogo(nome = nome, div = div, ano = ano, hometeam = home_team, awayteam = away_team, regiao = regiao))

        #Tabela TPC
        ListaTCP.append(TPC(CampAno = ano, Div = div, Time = home_team))
        ListaTCP.append(TPC(CampAno = ano, Div = div, Time = away_team))

TimesTotal = list(set(ListaTimes))
CampTotal = list(set(ListaCamp))
TCPTotal = list(set(ListaTCP))

TCPTotal
# Out:
# [TPC(CampAno = '2023', Div = 'T1', Time = 'Istanbulspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Kayserispor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Catanzaro'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Palermo'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Almeria'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Karagumruk'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Galatasaray'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Antalyaspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Cittadella'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Rizespor'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Mallorca'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Karagumruk'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Reggiana'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Alaves'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Villarreal'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Trabzonspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Sampdoria'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Antalyaspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Sivasspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Parma'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Fenerbahce'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Venezia'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Sivasspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Antalyaspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Ternana'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Samsunspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Karagumruk'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Buyuksehyr'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Ath Madrid'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Samsunspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Trabzonspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Ascoli'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Sampdoria'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Spezia'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Granada'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Pendikspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Modena'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Pendikspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Buyuksehyr'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Sudtirol'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Galatasaray'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Istanbulspor'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Cadiz'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Samsunspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Besiktas'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Lazio'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Cittadella'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Fenerbahce'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Besiktas'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Konyaspor'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Getafe'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Kasimpasa'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Villarreal'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Galatasaray'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Gaziantep'),
#  TPC(CampAno = '2023', Div = 'T1', Time = '
),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Fenerbahce'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Lazio'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Mallorca'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Antalyaspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ad. Demirspor'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Celta'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Sassuolo'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Bologna'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Karagumruk'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Besiktas'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Genoa'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Kasimpasa'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Betis'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Kayserispor'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Napoli'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Reggiana'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Monza'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Barcelona'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Atalanta'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Sivasspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Hatayspor'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Napoli'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Parma'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Osasuna'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Catanzaro'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Alanyaspor'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Bologna'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Samsunspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Pisa'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Getafe'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Gaziantep'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Ankaragucu'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Juventus'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Venezia'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Almeria'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Sudtirol'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Kasimpasa'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Inter'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Milan'),
#  TPC(CampAno = '2023', Div = 'SP1', Time = 'Villarreal'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Hatayspor'),
#  TPC(CampAno = '2023', Div = 'I1', Time = 'Frosinone'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Palermo'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Pendikspor'),
#  TPC(CampAno = '2023', Div = 'T1', Time = 'Istanbulspor'),
#  TPC(CampAno = '2023', Div = 'I2', Time = 'Bari')]

# %%
nome = 'I1 Italia 2023'
info = nome.split()
with app.app_context():
    timesNoCamp = TPC.query.filter_by(Divisao = info[0], CampAno = info[2])

lista = timesNoCamp
lista
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\pedro\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\base.py:2191, in _entity_namespace_key(entity, key, default)
#    2190     else:
# -> 2191         return getattr(ns, key)  # type: ignore
#    2192 except AttributeError as err:
#
# AttributeError: type object 'TPC' has no attribute 'Divisao'
#
# The above exception was the direct cause of the following exception:
#
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[25], line 4
#       2 info = nome.split()
#       3 with app.app_context():
# ----> 4     timesNoCamp = TPC.query.filter_by(Divisao = info[0], CampAno = info[2])
#       6 lista = timesNoCamp
#       7 lista
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\orm\query.py:1998, in Query.filter_by(self, **kwargs)
#    1971 r"""Apply the given filtering criterion to a copy
#    1972 of this :class:`_query.Query`, using keyword expressions.
#    1973
#    (...)
#    1994
#    1995 """
#    1996 from_entity = self._filter_by_zero()
# -> 1998 clauses = [
#    1999     _entity_namespace_key(from_entity, key) == value
#    2000     for key, value in kwargs.items()
#    2001 ]
#    2002 return self.filter(*clauses)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\orm\query.py:1999, in <listcomp>(.0)
#    1971 r"""Apply the given filtering criterion to a copy
#    1972 of this :class:`_query.Query`, using keyword expressions.
#    1973
#    (...)
#    1994
#    1995 """
#    1996 from_entity = self._filter_by_zero()
#    1998 clauses = [
# -> 1999     _entity_namespace_key(from_entity, key) == value
#    2000     for key, value in kwargs.items()
#    2001 ]
#    2002 return self.filter(*clauses)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\base.py:2193, in _entity_namespace_key(entity, key, default)
#    2191         return getattr(ns, key)  # type: ignore
#    2192 except AttributeError as err:
# -> 2193     raise exc.InvalidRequestError(
#    2194         'Entity namespace for "%s" has no property "%s"' % (entity, key)
#    2195     ) from err
#
# InvalidRequestError: Entity namespace for "TPC" has no property "Divisao"
